# %%
X<-matrix(rnorm(500000),5000,100)

# %%
X<-cbind(rep(1,nrow(X)),X)

# %%
w<-matrix(rnorm(101),101,1)

# %%
Z<-X%*%w

# %%
P_hat<-1/(1+exp(-Z))

# %%
Z_order<- order(Z)

# %%
plot(Z[Z_order,],P_hat[Z_order,],type = "l")
# Out:
# plot without title
