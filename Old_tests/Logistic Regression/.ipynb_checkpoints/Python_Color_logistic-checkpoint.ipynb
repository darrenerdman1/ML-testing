# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from mpl_toolkits.mplot3d import Axes3D

# %%
data=pd.read_csv("Color.txt", sep="\t")

# %%
data.isnull().sum(axis=0)
# Out:
# X1    0
# X2    0
# X3    0
# Y     0
# dtype: int64

# %%
#Looks like most of the colors on the RGB scale repeat, logically. Also, 
#11 of them were labels with both one and 2, which is not desirable. Just removed them from the second label,
data.drop_duplicates(inplace=True)
#11 of them were labels with both one and 2, which is not desirable. Just removed them from both labels,
#As is was a small data set
data.drop_duplicates(subset=['X1','X2','X3'],keep=False,inplace=True)

# %%
len(data)
# Out:
# 51422

# %%
data=np.matrix(data)

# %%
data
# Out:
# matrix([[179, 165, 123,   2],
#         [ 42,  28, 163,   2],
#         [  1, 142, 255,   2],
#         ...,
#         [ 56, 104, 152,   1],
#         [102, 150, 222,   1],
#         [ 54, 103, 151,   1]])

# %%
data[:, [0, 1, 2]][data[:, 3] == 1]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-100-1c3b97e535fc> in <module>
# ----> 1 data[:, [0, 1, 2]][data[:, 3] == 1]
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/matrixlib/defmatrix.py in __getitem__(self, index)
#     188
#     189         try:
# --> 190             out = N.ndarray.__getitem__(self, index)
#     191         finally:
#     192             self._getitem = False
#
# IndexError: boolean index did not match indexed array along dimension 1; dimension is 3 but corresponding boolean dimension is 1

# %%
# %matplotlib notebook
fig = plt.figure(figsize=(8,9))
ax = fig.add_subplot(111, projection='3d')

ax.scatter(data[:,0],data[:,1],data[:,2],s=1)
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
#Min max normalize
#X is data set to normalize, X_tr is data set to normalize bassed on
def norm(X,X_tr):
    X_tr_min=X_tr.min(0)
    X_tr_max=X_tr.max(0)
    X=(X-X_tr_min)/(X_tr_max-X_tr_min)
    return(X)

# %%
#Just a test of normalizer, doing min max
norm(data,data)
# Out:
# matrix([[0.29019608, 0.33333333, 0.48235294, 0.        ],
#         [0.28627451, 0.32941176, 0.47843137, 0.        ],
#         [0.28235294, 0.3254902 , 0.4745098 , 0.        ],
#         ...,
#         [0.24313725, 0.25098039, 0.1372549 , 1.        ],
#         [0.22745098, 0.23921569, 0.11372549, 1.        ],
#         [0.40392157, 0.41568627, 0.2       , 1.        ]])

# %%
#Shuffle data
np.random.shuffle(data)

# %%
data.shape
# Out:
# (51422, 4)

# %%
k=10

# %%
data_sets=np.array_split(data,k)

# %%
for j in range(k):
    test=data_sets[j]
    train=np.vstack(data_sets[:j]+data_sets[(j+1):])
    #make sure to normalize test data first, based on train. Add column of ones
    X_test=norm(test[:,-1],train[:,:-1])
    np.hstack(np.ones((X_test.shape[0],1)),X_test)
    y_test=norm(test[:,-1],train[:,-1])

    #normalize train and add ias column
    X_train=norm(train[:,-1],train[:,:-1])
    np.hstack(np.ones((X_train.shape[0],1)),X_train)
    y_train=norm(train[:,-1],train[:,-1])
    
    w=np.random.randn(4,1)
    epochs=20000
    eta=.000005
    for i in range(epochs):
        p=1/(1+np.exp(-X@w))
        Error.append(cost(y,p))
        epoch.append(i)
        w=w-eta*X.T@(p-y)

# %%
len(np.vstack((data_sets[:0]+data_sets[1:])))
# Out:
# 46279

# %%
data_sets[9:]
# Out:
# [matrix([[187, 173, 131,   2],
#          [177, 178, 146,   2],
#          [111, 121, 229,   2],
#          ...,
#          [ 56, 104, 152,   1],
#          [102, 150, 222,   1],
#          [ 54, 103, 151,   1]])]

# %%
data[:,:-1]
# Out:
# matrix([[179, 165, 123],
#         [ 42,  28, 163],
#         [  1, 142, 255],
#         ...,
#         [ 56, 104, 152],
#         [102, 150, 222],
#         [ 54, 103, 151]])
